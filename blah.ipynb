# %%
import random

CHOICES = [
    "apples",
    "bananas",
    "cherries",
    "dates",
    "elderberries",
    "figs",
    "grapes",
    "huckleberries",
    "imbers",
    "juneberries",
    "kiwis",
]


def generate_long_results():
    for _ in range(1000):
        for y in range(5):
            print(random.choice(CHOICES), end=" ")
        print()


generate_long_results()
# Out:
# juneberries figs cherries grapes cherries
# cherries cherries huckleberries apples huckleberries
# huckleberries apples bananas dates juneberries
# grapes kiwis elderberries imbers huckleberries
# kiwis cherries bananas apples elderberries
# figs cherries cherries huckleberries kiwis
# kiwis apples kiwis grapes imbers
# bananas huckleberries imbers apples figs
# huckleberries elderberries huckleberries kiwis figs
# apples apples elderberries elderberries cherries
# apples elderberries dates bananas cherries
# grapes juneberries figs huckleberries bananas
# grapes huckleberries bananas dates huckleberries
# figs huckleberries dates elderberries imbers
# huckleberries figs huckleberries huckleberries cherries
# dates kiwis juneberries juneberries imbers
# bananas dates juneberries apples apples
# apples bananas juneberries apples elderberries
# elderberries cherries apples figs imbers
# elderberries kiwis cherries elderberries dates
# dates cherries elderberries cherries figs
# ...
