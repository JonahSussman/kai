# %%
import sys
sys.path.append("../..")

import subprocess

def git_diff(file1, file2):
    command = ['git', 'diff', '--no-index', file1, file2]
    result = subprocess.run(command, capture_output=True, text=True)
    return result.stdout

# %%
import os

from kai.model_provider import ModelProvider
from kai.models.file_solution import guess_language
from kai.models.kai_config import KaiConfigModels
from kai.llm_io_handler import get_prompt
from kai.constants import PATH_GIT_ROOT

model_config = KaiConfigModels(
    provider="ChatIBMGenAI",
    template=os.path.join(PATH_GIT_ROOT, "notebooks/jonah/templates/alpaca_format.jinja"),
    args={
        "model_id": "mistralai/mistral-7b-instruct-v0-2",
    }
)
model_provider = ModelProvider(model_config)

reasoning = """1. **RemoteEJBClient.java to RemoteRestClient.java**:
   - **Technology Shift**: The original `RemoteEJBClient.java` used EJBs with JNDI lookups to access remote stateless and stateful beans. In contrast, `RemoteRestClient.java` employs RESTful web services and the MicroProfile Rest Client for remote interactions.
   - **Configuration**: Quarkus uses annotations like `@RestClient` and `@RegisterRestClient(configKey="api-key")` to inject REST clients, simplifying the configuration compared to JNDI properties.
   - **Invocation**: The invocation logic in `RemoteEJBClient.java` involves manual lookups and method calls on EJBs, whereas `RemoteRestClient.java` directly calls methods on injected REST clients (`CounterClient` and `CalculatorClient`).
   - **Logging and Exception Handling**: Quarkus uses `Log` for logging instead of `System.out.println`. Exception handling is also simplified with runtime exceptions in Quarkus.

2. **RemoteCalculator and RemoteCounter to REST Clients**:
   - The `RemoteCalculator` and `RemoteCounter` EJBs in Jakarta EE were replaced with REST clients (`CalculatorClient` and `CounterClient`) in Quarkus.
   - **Interfaces**: The EJB interfaces were replaced with Java interfaces annotated with JAX-RS annotations like `@GET`, `@Path`, and `@QueryParam` to define REST endpoints.
   - **Dependencies**: EJB dependencies and configurations were removed in favor of REST client dependencies and annotations."""

pb_vars = {
    "example": {
        "src_file_name": "RemoteEJBClient.java",  # To RemoteRestClient.java
        "src_file_language": guess_language(None, "RemoteEJBClient.java"),
        "src_file_contents": open("RemoteEJBClient.java", "r").read(),
        "incidents": [
            {
                "analysis_line_number": 115+1,
                "analysis_message": "The app is trying to access local resource by HTTP, please try to migrate the resource to cloud",
            },
            {
                "analysis_line_number": 118+1,
                "analysis_message": "The app is trying to access local resource by HTTP, please try to migrate the resource to cloud",
            },
            {
                "analysis_line_number": 157+1,
                "analysis_message": "The app is trying to access local resource by HTTP, please try to migrate the resource to cloud",
            },
            {
                "analysis_line_number": 160+1,
                "analysis_message": "The app is trying to access local resource by HTTP, please try to migrate the resource to cloud",
            },
        ],
        "reasoning": reasoning,
        # "diff": git_diff("RemoteEJBClient.java", "RemoteRestClient.java"),
        "dst_file_name": "RemoteRestClient.java",  # To RemoteRestClient.java
        "dst_file_language": guess_language(None, "RemoteRestClient.java"),
        "dst_file_contents": open("RemoteRestClient.java", "r").read(),
    },
    "input": {
        "src_file_name": "RemoteEJBClientClass.java",
        "src_file_language": guess_language(None, "RemoteEJBClientClass.java"),
        "src_file_contents": open("RemoteEJBClientClass.java", "r").read(),
        "incidents": [
            {
                "analysis_line_number": 59,
                "analysis_message": "The app is trying to access local resource by HTTP, please try to migrate the resource to cloud",
            },
            {
                "analysis_line_number": 74,
                "analysis_message": "The app is trying to access local resource by HTTP, please try to migrate the resource to cloud",
            }
        ],
    }
}

prompt = get_prompt(model_provider, pb_vars)

print(prompt)
# Out:
# You are an assistant trained on migrating enterprise JavaEE code to Quarkus.
#
# ### Instruction:
#
# Given the following input file, migrate the following code to quarkus and fix the listed issues. Optionally reason through what changes are required and produce a diff that fixes the issue.
#
# ### Input:
#
# File name: RemoteEJBClient.java
# File contents:
# ```java
#
# /*
#  * JBoss, Home of Professional Open Source
#  * Copyright 2015, Red Hat, Inc. and/or its affiliates, and individual
#  * contributors by the @authors tag. See the copyright.txt in the
#  * distribution for a full listing of individual contributors.
#  *
#  * Licensed under the Apache License, Version 2.0 (the &#34;License&#34;);
#  * you may not use this file except in compliance with the License.
#  * You may obtain a copy of the License at
#  * http://www.apache.org/licenses/LICENSE-2.0
#  * Unless required by applicable law or agreed to in writing, software
# ...

# %%
response = model_provider.llm.invoke(prompt)
print(response.content)
# Out:
# Reasoning: 1. **RemoteEJBClientClass.java to RemoteRestClientClass.java**:
#
# - **Technology Shift**: The original `RemoteEJBClientClass.java` used EJBs with JNDI lookups to access remote stateless and stateful beans. In contrast, `RemoteRestClientClass.java` employs RESTful web services and the MicroProfile REST Client for remote interactions.
# - **Configuration**: Quarkus uses annotations like `@Inject` and `@RegisterRestClient` to inject REST clients, simplifying the configuration compared to JNDI properties.
# - **Invocation**: The invocation logic in `RemoteEJBClientClass.java` involves manual lookups and method calls on EJBs, whereas `RemoteRestClientClass.java` directly calls methods on injected REST clients (`NameCapitalizerClient` and `PhoneNumberGeneratorClient`).
# - **Logging and Exception Handling**: Quarkus uses `Logger` for logging instead of `System.out.println`. Exception handling is also simplified with runtime exceptions in Quarkus.
#
# ...
